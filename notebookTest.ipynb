# %%
print("Hello Alphonse!")
# Out:
# Hello Alphonse!

# %%
print("Hello Alphonse!")
# Out:
# Hello Alphonse!

# %%
print("Hello Alphonse")
# Out:
# Hello Alphonse

# %%
def namecal():
    name = "Alphonse"
    print(f"My name is {name}")
namecal()
# Out:
# My name is Alphonse

# %% [markdown]
# Functions

# %%
print("test")
# Out:
# test
